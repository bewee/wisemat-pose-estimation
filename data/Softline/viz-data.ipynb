# %%
import sys
sys.path.append('../../')

# %%
import numpy as np
import matplotlib.pyplot as plt
from lib.viz import plot_mattress
from lib.constants import set_mattress_format

# %%
set_mattress_format('softline')

# %%
RECORDING = '2021-05-07-Messung_2'
SAMPLE = '2021-05-07-12-48-33-Messung_2_4108'

# %%
data = np.genfromtxt(f"Frames_csv/{RECORDING}/{SAMPLE}.csv", delimiter=',')
data.shape
# Out:
# (26, 64)

# %%
plt.figure(1).set_size_inches(8, 8)
plot_mattress(np.swapaxes(data, 0, 1))
# Out:
# <AxesSubplot:>
